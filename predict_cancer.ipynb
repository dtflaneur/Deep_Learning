# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/L44ZNN5RAbxWEEvK1qAyEG8q2/train.csv')
test = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/vXqe54K2NP9Obg2ELkyBRZa2/test.csv')

# %%
train.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25          130.00     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
test.head()
# Out:
#        id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0   91485        20.59         21.24          137.80     1320.0
# 1  914862        15.04         16.74           98.73      689.4
# 2   91504        13.82         24.49           92.33      595.9
# 3   91505        12.54         16.32           81.25      476.3
# 4  915143        23.09         19.83          152.10     1682.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.10850            0.1644         0.21880              0.11210
# 1          0.09883            0.1364         0.07721              0.06142
# 2          0.11620            0.1681         0.13570              0.06759
# 3          0.11580            0.1085         0.05928              0.03279
# 4          0.09342            0.1275         0.16760              0.10030
#
#    symmetry_mean           ...             radius_worst  texture_worst  \
# ...

# %%
X_train = train.iloc[:,2:]
y_train = train.iloc[:,1]
X_test = test.iloc[:,1:]

# %%
#y_train.head()

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %%
from keras.models import Sequential
from keras.layers import Dense

classifier = Sequential() # Initialising the ANN
classifier.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 30))
classifier.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
classifier.fit(X_train, y_train, batch_size = 128, epochs = 30, verbose = 2)
# Out:
# Epoch 1/30
#  - 0s - loss: 0.6930 - acc: 0.5711
# Epoch 2/30
#  - 0s - loss: 0.6925 - acc: 0.6112
# Epoch 3/30
#  - 0s - loss: 0.6920 - acc: 0.6112
# Epoch 4/30
#  - 0s - loss: 0.6914 - acc: 0.6112
# Epoch 5/30
#  - 0s - loss: 0.6908 - acc: 0.6112
# Epoch 6/30
#  - 0s - loss: 0.6900 - acc: 0.6112
# Epoch 7/30
#  - 0s - loss: 0.6891 - acc: 0.6112
# Epoch 8/30
#  - 0s - loss: 0.6881 - acc: 0.6112
# Epoch 9/30
#  - 0s - loss: 0.6867 - acc: 0.6112
# Epoch 10/30
#  - 0s - loss: 0.6849 - acc: 0.6192
# Epoch 11/30
#  - 0s - loss: 0.6825 - acc: 0.6473
# Epoch 12/30
#  - 0s - loss: 0.6794 - acc: 0.7114
# Epoch 13/30
#  - 0s - loss: 0.6751 - acc: 0.7936
# Epoch 14/30
#  - 0s - loss: 0.6695 - acc: 0.8577
# Epoch 15/30
#  - 0s - loss: 0.6622 - acc: 0.9038
# Epoch 16/30
#  - 0s - loss: 0.6527 - acc: 0.9218
# Epoch 17/30
#  - 0s - loss: 0.6409 - acc: 0.9279
# Epoch 18/30
#  - 0s - loss: 0.6262 - acc: 0.9379
# Epoch 19/30
#  - 0s - loss: 0.6095 - acc: 0.9379
# Epoch 20/30
# ...

# %%
y_pred = classifier.predict(X_test)
y_pred = [ 1 if y>=0.5 else 0 for y in y_pred ]

# %%
#y_pred

# %%
pred_df = pd.DataFrame({'id':test['id'],'predictions':y_pred})

# %%
pred_df.head()
# Out:
#        id  predictions
# 0   91485            1
# 1  914862            0
# 2   91504            1
# 3   91505            0
# 4  915143            1

# %%
pred_df.to_csv('/home/user/workspace/predictions.csv')
